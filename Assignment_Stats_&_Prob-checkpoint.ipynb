# %%
"""

# Q1. Fair Toss three times ? 
a.) What is the prob of three head (HHH) ? 
b.) What is the prob that exactly one head ? 
c.) Given that you have already observed at least one head, 
    what is the prob of atleast two heads ? 
""""
"""
Answer - 
a.) 
(HHH) 
(HHT)
(HTT)
(TTT)
(THH)
(TTH)
(HTH)
(THT)
  2.    2.    2   = 8
  -     -     - 
Ans - 1/8 

b.) 

H T T
- - -
T H T 
T T H 


1/8 * 3 = 3/8 


c.) 

Conditional Prob
P1 - you observ atleast one head 
P2 - you observ atleast two head

P(P2| P1) = P(P2 intersection P1) / P1

P1 = for atleast one head HTT, HHT, HHH
P1 = 1 - P(no heads)
P1 = 1 - 1/8 
P1 = 7/8

# no head, 1 head, 2 head, 3head

P2 = for atleast two heads
P2 = 4/8
P2 = 1 - ( no head ) - (one head)
   = 1 - 1/8 - 3/8 
   = 1 - 4/8 
   = 1 - 1/2 
   = 1/2 
P2 = 2 heads + 3 heads 
   = 3/8 + 1/8 
   = 4/8 
   = 1/2 
P(P2 | P1 ) = P(P2 intersection P1 )/ P1 
            = P2/ P1 
            = (4/8) / (7/8)
            = 4/7 
"""

# %%
"""
In my town, it's rainy one third of the days. Given that it is rainy, there will 
be heavy traffic with probability 12, and given that it is not rainy, there will 
be heavy traffic with probability 14. If it's rainy and there is heavy traffic, 
I arrive late for work with probability 12. On the other hand, the probability 
of being late is reduced to 18 if it is not rainy and there is no heavy traffic. 
In other situations (rainy and no traffic, not rainy and traffic) the 
probability of being late is 0.25. You pick a random day.

    What is the probability that it's not raining and there is heavy traffic and I am not late?
    What is the probability that I am late?
    Given that I arrived late at work, what is the probability that it rained that day?

-----------------------------------------------------
Q2. Town 

1/3 of the days it is raining
Given on a rainy - 
* there we will heavy traffic  - 1/2 

Given on a non rainy day - 
* there will be heavy traffic - 1/4 

** If it is raining & heavy traffic - office late - 1/2 
** If is is not raining & there is no traffic - office late - 1/8 

** Other situation prob of reaching office late is 0.25 

a.) What is the prob, that it is not raining, and there is heavy traffic - and I am not late ? 
b.) What is the prob, that I am late ? 
c.) Given that I came office late, what is the prob that it rained that day ? 
"""

# %% [markdown]
# ![Screenshot 2021-09-18 at 8.07.11 PM.png](data:image/png;base64,...)

# %%
"""
a.) 

b.) 1/12 + 1/24 + 1/24 + 1/16
    11/48
c.) Given that I came office late, what is the prob that it rained that day 
    P(R|L) = P(R intersection L )/ P(L) 

    P(R intersection L) = P(RTL) + P(RT^L)
                        = 1/ 12 + 1/24
                        = 1/8
    P(R|L) = (1/8) / (11/48)
          = 6/11              

"""

# %%
"""
Q3. There are 3 coins 
  - only 2 are fair coins  
  - 1 is unfair and always gives you heads

a.) You pick a random coin, & toss it - what is the prob that it gives you heads ? 
b.) You pick a random coin & and it gets head. What is the prob that it is unfair coin ? 
"""

# %% [markdown]
# ![Screenshot 2021-09-18 at 8.43.27 PM.png](data:image/png;base64,...)

# %%
"""
a) 
Unfair & head = (1/3) * 1 
Fair & Head = (2/3) * 1/2
Unfair & Head + Fair & Head = 1/3 + 1/3 = 2/3 


b) head has been observed & what is the prob that it is unfair coin
P( Unfair Coin | Head ) = P(Unfair intersection Head) / P(H)  =  (1/3)  / (2/3) = 1/2

"""
