# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
df_sent = pd.read_csv("Sentiment.csv")

# %%
df_sent.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# 0                     1.0000            NaN  ...              NaN
# 1                     1.0000            NaN  ...              NaN
# 2                     0.6629            NaN  ...              NaN
# 3                     0.7039            NaN  ...              NaN
# 4                     1.0000            NaN  ...              NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
# 1            26             NaN                 NaN
# 2            27             NaN                 NaN
# 3           138             NaN                 NaN
# 4           156             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2  RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3  RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
#
#                tweet_created            tweet_id  tweet_location  \
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN
# 1  2015-08-07 09:54:46 -0700  629697199560069120             NaN
# 2  2015-08-07 09:54:46 -0700  629697199312482304             NaN
# 3  2015-08-07 09:54:45 -0700  629697197118861312           Texas
# 4  2015-08-07 09:54:45 -0700  629697196967903232             NaN
#
#                 user_timezone
# 0                       Quito
# 1                         NaN
# 2                         NaN
# 3  Central Time (US & Canada)
# 4                     Arizona
#
# [5 rows x 21 columns]

# %%
df_sednt=df_sent.loc[:,["candidate","text","sentiment"]]

# %%
df_sent['sentiment'].value_counts()
# Out:
# Negative    6546
# Neutral     2642
# Positive    1753
# Name: sentiment, dtype: int64

# %%
df_sent['candidate'].value_counts()
# Out:
# No candidate mentioned    6379
# Donald Trump              2094
# Ted Cruz                   422
# Jeb Bush                   350
# Ben Carson                 312
# Marco Rubio                234
# Mike Huckabee              228
# Rand Paul                  225
# Chris Christie             220
# Scott Walker               202
# John Kasich                188
# Name: candidate, dtype: int64

# %%
df_sent.groupby(['candidate','sentiment']).size()
# Out:
# candidate               sentiment
# Ben Carson              Negative      134
#                         Neutral        38
#                         Positive      140
# Chris Christie          Negative      158
#                         Neutral        34
#                         Positive       28
# Donald Trump            Negative     1375
#                         Neutral       347
#                         Positive      372
# Jeb Bush                Negative      267
#                         Neutral        52
#                         Positive       31
# John Kasich             Negative       64
#                         Neutral        40
#                         Positive       84
# Marco Rubio             Negative       85
#                         Neutral        42
#                         Positive      107
# Mike Huckabee           Negative      121
#                         Neutral        45
#                         Positive       62
# No candidate mentioned  Negative     3909
#                         Neutral      1840
#                         Positive      630
# Rand Paul               Negative      118
#                         Neutral        54
#                         Positive       53
# Scott Walker            Negative      132
#                         Neutral        32
#                         Positive       38
# Ted Cruz                Negative      141
#                         Neutral        86
#                         Positive      195
# dtype: int64
