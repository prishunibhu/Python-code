# %%
Process of two types

*Deterministic/Stochastics or Randomness
*Why randomness? No system is perfect and will have randomness or probability measurement basis the various factors


Random process - Data generating phenomenon . The system ability to generate data

Descriptive Statistics 

Nothing to do with the random process. It just shows/describes data

Frequency distribution/graphs/ Data summary

Inferential statistics:
    
    basically the ability to determine / infer more data with primary data
    
    advance statistics - cohort analysis/pareto analysis
    
    likewise - data is differed into primary and secondary

primary - surverys/questionarrie/polls

secondary - huge data with from the past .

data - qualitative,quantative

qualitative - dichotomic(True/false , yes/no M/f)/polynomic(multiple)
quantitative - discrete/contionus

# %%
Charts

Polygon - A line chart.point plotted.

Ogive - same as above but generatesCumulative frequency graph

Contigency table - example

	Light	Regular	Dark	Total
Male	20	40	50	110
Female	50	20	20	90
Total:	70	60	70	200

histogram - univariate and discrete data
scatterplot - continous vs continous
bar - multivariate and discrete

# %%
why mean is important than median and mode

Mean has important connection to random process

Mean is base for variance/SD and many other advance statistics concepts

Mean deviation vs standard deviation

Mean absolute deviation(MAD) = sum(abs(x-mean(x)) / n

standard error of the mean  = SD/sqrt(n)
Standard error of the mean (SEM) measured how much discrepancy there 
is likely to be in a sample's mean compared to the population mean

# %%
Sampling

Random

Non random - is a sequence/algorithm

simple - completely random. ever sample has chance 1/n.
stratified - divide the sample into appropriate group and sample equally among all groups
cluster -   divide into group and the take a group as a kind of same cluster samples
systematic - every nth piece of a sample

# %%
sample space - outcome of random experiment

Discrete finite(anything countable / whole numbers)- age/no of ppl/outcome of coin - 

Countable infinite - no of times u have to toss a coin to get head( random future but countable)

infinite space(anything measurable/real values) -

# %%
connections between probability and statistics

probability - is a lab. assumptions/derive formulas/experiments

stats - reality


sample mean will lead to population mean with probability 1 when population tends to infinity.

# %%
Probablility

Sample point  - outcome of experiment


probability 0 means - rare event. it is still an event. 
eg  - what is the probability of the dart will hit a specific point in the board.

p(1/infinity) = 0 . since th points in the dart board in infinite/infinite space.

probability of all events should be = 1

0 <=p <=1

sample space - in a dice 1 ,2 ,3,4,5,6 is a sample space

Combinations nCr = n!/(n-r)! * r!

# %%
P(A)  - Toss of an head
P(a complement) - Toss of a tail
P(A) + P(A complement )  = 1
P(AUB) = p(A) + P(B) - P(A intersect B)  => Additive rule

# %%
mutually exclusive - they are two different events and one happens, the other cannot happen. 
                   - no intersection between two
    
                    Mutually exclusive events are events that can not happen at the same time. 
                Examples include: right and left hand turns, even and odd numbers on a die, winning and losing a game
                

P(A intersect B ) = 0 for mutually exclusive

P ( A union B ) = P(A) + P(B)

# %%
Conditional proability

It is the occurrence of a condition that happens to alter the probability of the event

eg - rolling a 6 in dice is 1/6.
But it is said that the dice has showed an even number . now the probability increases to 1/3.

P(A/B) = P(A intersect B)/P(B)
        = (p(B/A)* P(A))/P(B)
it is naive bayes  theorem

# %%
Independent
knowing one event occurred doesn't change the probability of the other event.
eg- tossing a coin and rolling a die are two independent events.

P(A intersect B) = P(A) * P(B)

# %%
Probability distribution is the maximum inference we can get

Probability mass function - For discrete data
Probability distribution function - continous data
Cumulation distribution function is the summation of the probability mass function

# %%
Weighted average function/Theoretical formulas:
    
mu=E(X)= sum(x * p(x))

mu/truth/ is a constant as long as the population remains.

Variance = E([x-mu]^2) = sum((x-mu)^2 * p(x))

SD =sqrt(variance)

True mean/true variance is based on p(X) and is impossible to compute in real time.

That is why we derived statistics where my mean is same as true mean(mu)

X bar - sample mean is a random since my sample changes and my E(X bar) varies.

All the statistical variables are random as they 

statistics - function applied to a sample variables

Therefore, statistics is a sample/random  variable

Kurtosis

Skewness- 

Mean squared error = SD(X bar)

# %%
Poisson Distribution - rare events

# %%
statistics is a function applied on a random sample  and hence is a random variable itself.

point estimator - any statistic.- tet

x bar- sample mean, mu - pop mean

x bar is an unbiased parameter if

e(x bar) = mu.

if it is not unbiased then the difference betwee

e(x bar) - mu = is the bias of the estimator x bar

Here the estimators can be any statistic like mean, SD etc

Expectation is a linear operator meaning E(ax) = a * E(x)

check this - https://www.youtube.com/watch?v=c1IUAjw_2zE
    
Now we will move to variance . This will help us to identify when e(x bar) will tend to become mu.

var[ax] = a^2 var(x)

check below image for details.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)#
#
# This derivative is applicable only when the random samples are independent of each other
#
# They do not have a covariance. only then this is applicable
#
# Also , var(x bar) will be 0 when the population tends to infinity
#
# SD(X bar) = standard mean error = sigma/ root(n)
#
# if S^2 is the variance of the sample then
#
# E(s^2) = sigma ^2 ( population variance)
#
#
# Biased variance trade off -
#
# accuracy precision trade off -

# %%
Binomial Distribution - is made up of bernouli trial. Measure success /failure. Discrete data.

Every outcome has a success or a failure.

Series of a success and failure distribution is called binomial distribution.

Real applications

Quality controls - nCx - x success out of n trials.

x is success, n = trials

P(x) =nCx * p^x * q^ n-x

P(X) must be greater than 0.95 to pass quality control.

p is the probability of a single trial

q=1-p

most cases p =0.5 and q=0.5

mu=np
var/sigma squared=npq

# %%
Poisson distribution - for rare events

events that relates with time, length, area, volume, distance

for example accidents. you get 3 accidents in less than 1 hour. what is the probability of getting in it next 1 hour

# %%
Continous probability distribution

we discuss probability of a space/area

probability of point is 0 since it is having infinite space.

p(x) = 0 and so we find
we find p(a<b<x)

Uniform distribution:
    
The probability is uniformly spread against a given area.

It has equal chances of occuring in all the regions and the probability graph can be as below.
----------
|        |
|        |
|        |
|        |

# %%
Normal/Gaussian Distribution:
    
f(x) - probability density func(continous)/probability mass func(discrete)

# %% [markdown]
# ![normal%20distribution.PNG](attachment:normal%20distribution.PNG)#

# %%
normal distribution tables are cumulative distribution(depends of the table)

X is a random variable having mean mu and sd as sigma

To normalize this, we have z having standard normal distribution with mean 0 and sd =1

z=x-mu/ sigma

z sigma = x-mu

x=z sigma+mu
and we can determine this using noraml table
    
    
eg:
    
Find P(2< X < 4) where x -> N(5,2) where 5 is mu and 2 is sigma

P(2) =z = (2-5)/2 = -3/2= -1.5
p(4) =z= (4-5)/2 = 1/2 = 0.5

Find the Z values for -1.5 to 0.5 using normal table

Therefore P(2<X<4) = z(-1.5)  - z(0.5) = .2417

# %%
Central Limit Theorem:
    
z=(xbar - mu)/(sigma * sqrt(n))

z is the limiting form of distribution. x bar follows normal distribution.

sample mean follows normal distribution

xbar tends to mu

Standard mean error - The Standard deviation of the sampling distribution of the x bar is called standard mean error

That is, we distribute the sample mean and we get SD of that distribution of the sample mean.

SME = sigma/sqrt(n)

# %%
point estimate:
    
point estimator or p hat = x/n 

where x is success and n is total population/sample

This is for discrete ones typically on binomial distribution concept.

sampling distribution of phat .

mean will be indicated as p and 

sd = sqrt(pq/n)= sqrt(p(1-p)/n)

This helps to give confidence intervals.

# %%
Confidence intervals: 
    
    This is calculated to determined the population mean. (mu) and how must the confidence band between mu and x bar is.
    
    mu = x bar +-  p(z) * sigma/sqrt(n)
    
    mu = xbar +-  p(z) * SME.
    
    here we can use sample deviation for sigma.

It deals with how confident you want to be that the actual mean falls within your margin of error

Normal distribution is applicable only for large samples

When samples are very less, it is difficult to calculate as small sample may not fit into normal distribution.

However, for small samples , we assume that the underlying population is normal.

mu = xbar +- p(t) * sigma/sqrt(n)

It follows a t distribution table.

Confidence leves tends to describe the z score 

For eg : 90% confidence means z score is 1.67

# %%
sample size:
    
SE or SME  = sigma/sqrt(n)

Necessary Sample Size = (Z-score)2 * StdDev* / (margin of error)2



My confidence level tends to z score.
