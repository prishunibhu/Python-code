# %%
import pandas as pd

# %%
df_cust=pd.read_csv(r"C:\Users\Priyadarshini\Downloads\Python datasets\customer_churn.csv")

# %%
df_cust.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_cust['TotalCharges'] = pd.to_numeric(df_cust['TotalCharges'],errors='coerce')
df_cust.dropna(inplace=True)
df_cust.drop(columns='customerID',inplace=True)

# %%
df_cust['gender'] = df_cust['gender'].str.lower().map({'male':0,'female':1})

# %%
df_cust.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       1              0     Yes         No       1           No
# 1       0              0      No         No      34          Yes
# 2       0              0      No         No       2          Yes
# 3       0              0      No         No      45           No
# 4       1              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df_cust['Partner'] = df_cust['Partner'].map({'Yes': 1, 'No': 0})
df_cust['Dependents'] = df_cust['Dependents'].map({'Yes': 1, 'No': 0})
df_cust['PhoneService']= df_cust['PhoneService'].map({'Yes': 1,'No': 0})
df_cust['MultipleLines']=df_cust['MultipleLines'].map({'No phone service':0, 'No': 1, "Yes": 2})
df_cust['InternetService']=df_cust['InternetService'].map({'DSL':0, 'Fiber optic':1, 'No':2})
df_cust['OnlineSecurity']=df_cust['OnlineSecurity'].map({'Yes':1, 'No':0, 'No internet service':2})
df_cust['OnlineBackup']=df_cust['OnlineBackup'].map({'Yes':1, 'No':0, 'No internet service':2})
df_cust['DeviceProtection']=df_cust['DeviceProtection'].map({'Yes':1, 'No':0, 'No internet service':2})
df_cust['TechSupport']=df_cust['TechSupport'].map({'Yes':1, 'No':0, 'No internet service':2})
df_cust['StreamingTV']=df_cust['StreamingTV'].map({'Yes':1, 'No':0, 'No internet service':2})
df_cust['StreamingMovies']=df_cust['StreamingMovies'].map({'Yes':1, 'No':0, 'No internet service':2})
df_cust['Contract']=df_cust['Contract'].map({'Month-to-month':0, 'One year':1, 'Two year':2})
df_cust['PaperlessBilling']=df_cust['PaperlessBilling'].map({'Yes':1, 'No':0})
df_cust['PaymentMethod']=df_cust['PaymentMethod'].map({'Electronic check':1, 'Mailed check':0, 'Bank transfer (automatic)':2, 'Credit card (automatic)':3})
df_cust['Churn']=df_cust['Churn'].map({'Yes':1,'No':0})

# %%
df_cust.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       1              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              0                0               0             1
# 1              1                0               1             0
# 2              1                0               1             1
# 3              0                0               1             0
# 4              1                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=pd.DataFrame(df_cust.iloc[:,:-1])
y=pd.DataFrame(df_cust.iloc[:,-1])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc= RandomForestClassifier(n_estimators=500)
rfc.fit(x_train,y_train)
ypred=rfc.predict(x_test)
# Out:
# <ipython-input-46-f588e6a0cb88>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train,y_train)

# %%
from sklearn.metrics import *

# %%
print("Accuracy Score",accuracy_score(ypred,y_test))
# Out:
# Accuracy Score 0.7953091684434968

# %%
importance=pd.Series(rfc.feature_importances_)

# %%
df_imp=pd.DataFrame(columns=['Feature','Importance'])

# %%
cols=list(df_cust.keys())
cols=cols[:-1]

# %%
df_imp['Feature']=cols
df_imp['Importance']=importance

# %%
df_imp
# Out:
#              Feature  Importance
# 0             gender    0.028302
# 1      SeniorCitizen    0.021125
# 2            Partner    0.022601
# 3         Dependents    0.019848
# 4             tenure    0.156284
# 5       PhoneService    0.004415
# 6      MultipleLines    0.023133
# 7    InternetService    0.026069
# 8     OnlineSecurity    0.042140
# 9       OnlineBackup    0.029128
# 10  DeviceProtection    0.024008
# 11       TechSupport    0.040336
# 12       StreamingTV    0.020985
# 13   StreamingMovies    0.020557
# 14          Contract    0.078648
# 15  PaperlessBilling    0.025549
# 16     PaymentMethod    0.050881
# 17    MonthlyCharges    0.176536
# 18      TotalCharges    0.189455

# %%
df_imp.sort_values(by='Importance',ascending=True,ignore_index=True,inplace=True)
df_imp
# Out:
#              Feature  Importance
# 0       PhoneService    0.004415
# 1         Dependents    0.019848
# 2    StreamingMovies    0.020557
# 3        StreamingTV    0.020985
# 4      SeniorCitizen    0.021125
# 5            Partner    0.022601
# 6      MultipleLines    0.023133
# 7   DeviceProtection    0.024008
# 8   PaperlessBilling    0.025549
# 9    InternetService    0.026069
# 10            gender    0.028302
# 11      OnlineBackup    0.029128
# 12       TechSupport    0.040336
# 13    OnlineSecurity    0.042140
# 14     PaymentMethod    0.050881
# 15          Contract    0.078648
# 16            tenure    0.156284
# 17    MonthlyCharges    0.176536
# 18      TotalCharges    0.189455

# %%
proba_valid=rfc.predict_proba(x_test)[:,1]
proba_valid
# Out:
# array([0.   , 0.738, 0.078, ..., 0.058, 0.102, 0.21 ])

# %%
proba_valid.shape
# Out:
# (1407,)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,proba_valid)
# Out:
# 0.8309646042319544

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot
import numpy as np

# %%
auc = roc_auc_score(np.array(y_test),proba_valid)
auc
# Out:
# 0.8309646042319544

# %%
fpr,tpr,threshold = roc_curve(np.array(y_test),proba_valid)

# %%
pyplot.plot(fpr,tpr,marker='.',label='Random')
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
pyplot.show()

# %%
print(classification_report(ypred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      1117
#            1       0.50      0.63      0.56       290
#
#     accuracy                           0.80      1407
#    macro avg       0.70      0.74      0.71      1407
# weighted avg       0.82      0.80      0.80      1407

# %%
print(confusion_matrix(ypred,y_test))
# Out:
# [[935 182]
#  [106 184]]

# %%
#precision - TP /(TP+FP)
#recall - TP /(TP+FN) - This is basis what is correctly predicted
#F1score - What percent of postive predictions were correct
#F1 score = 2 * Recall * Precision/(Recall+Pre)
#Support- Total no of samples of that prediction .
