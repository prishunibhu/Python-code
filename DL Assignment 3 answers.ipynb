# %%
#Assignment 1

1.	Briefly describe the disadvantages of Flattening (as first layer or after Input) and how do you overcome those issues ?

Flattening is the process of converting my x * y* c image into 1 column vector.

This defines the input neuron required for processing the model.

Suppose we have 500* 500* 3 image and there are 50k such images . Then it requires

input neurons = 500 * 500 * 3 * 50000 which is high in number and in turn needs so many weights for processing also thereby leading to system crash. We may not have processing power 
to handle such complex architecture.

In order to avoid this, we use the Convolutiion neural network topology to be able to extract features in details and also compress the size of the image at the same time.

# %%
# Assignment 2

2.	Stanford Vision department, has collected and annotated images of 120 breeds of dogs from ImageNet. Dataset can be found here.
a.	Prepare an EDA sheet & explain what you understand from this data. What would be your approach? 
b.	With a limited number of training images per class, what extra steps will you incorporate for a good model? 
c.	Iterate over and try different architecture and topologies and preserve the results of each experiment using TensorBoard. Also, save major metrics in an Excel (or try W&B). 


a) There are 10222 total training images
   Each image is different in shape.
   The average image height and width are 386.47 and 443.33 respectively
   All the image has 3 channels
   There are totally 120 different breeds of dog as the predictor variable
   Each breed ranges between  125 images  66 images of data
   The labels are converted into 1- 120 representing each breed.
   The images are resized into (150,150) for processing.

b)There are at most of  125 images of each breed . Therefore, we need to increase the number of training images for each breed to be able to produce a better efficient mode
and has better learning of the problem statement

For this we may have to do augmentation:

*Augementation creates copies of the original image with one or more variations to the original image. Variations may include

a)Horizontal flip
b)vertical flip
c)rotation range
d)zoom range

and many more.

This creates random copies of the original image applying this parameter changes like zoom,horizontal flip. This will not be saved externally but will be used for model learning.
c.Colab link: https://colab.research.google.com/drive/1VvubdAer1FN9T-vU-SKCmkGM22j18qNz

# %%
VGG16 result:
model6.fit(train_gen, validation_data=val_gen, epochs=25, batch_size=batchsize)
# Out:
# Epoch 1/25
# 288/288 [==============================] - 321s 1s/step - loss: 4.7986 - acc: 0.0080 - val_loss: 4.7871 - val_acc: 0.0157
# Epoch 2/25
# 288/288 [==============================] - 299s 1s/step - loss: 4.7872 - acc: 0.0112 - val_loss: 4.7866 - val_acc: 0.0166
# Epoch 3/25
# 288/288 [==============================] - 298s 1s/step - loss: 4.7864 - acc: 0.0115 - val_loss: 4.7862 - val_acc: 0.0166
# Epoch 4/25
# 288/288 [==============================] - 295s 1s/step - loss: 4.7860 - acc: 0.0120 - val_loss: 4.7859 - val_acc: 0.0166
# Epoch 5/25
# 288/288 [==============================] - 294s 1s/step - loss: 4.7855 - acc: 0.0114 - val_loss: 4.7855 - val_acc: 0.0157
# Epoch 6/25
# 288/288 [==============================] - 292s 1s/step - loss: 4.7849 - acc: 0.0118 - val_loss: 4.7852 - val_acc: 0.0166
# Epoch 7/25
# 288/288 [==============================] - 290s 1s/step - loss: 4.7847 - acc: 0.0120 - val_loss: 4.7849 - val_acc: 0.0166
# Epoch 8/25
# ...

# %%
final_model.fit(train_gen, validation_data=val_gen, epochs=25, batch_size=32) # using inception still a bad model
# Out:
# Epoch 1/25
# 269/269 [==============================] - 242s 869ms/step - loss: 4.6892 - acc: 0.0197 - val_loss: 4.7284 - val_acc: 0.0000e+00
# Epoch 2/25
# 269/269 [==============================] - 233s 864ms/step - loss: 4.6676 - acc: 0.0794 - val_loss: 4.7604 - val_acc: 0.0000e+00
# Epoch 3/25
# 269/269 [==============================] - 234s 869ms/step - loss: 4.6472 - acc: 0.1697 - val_loss: 4.7924 - val_acc: 0.0000e+00
# Epoch 4/25
# 269/269 [==============================] - 236s 876ms/step - loss: 4.6272 - acc: 0.2369 - val_loss: 4.8250 - val_acc: 0.0000e+00
# Epoch 5/25
# 269/269 [==============================] - 232s 864ms/step - loss: 4.6074 - acc: 0.3048 - val_loss: 4.8574 - val_acc: 0.0000e+00
# Epoch 6/25
# 269/269 [==============================] - 231s 857ms/step - loss: 4.5882 - acc: 0.3435 - val_loss: 4.8899 - val_acc: 0.0000e+00
# Epoch 7/25
# ...

# %%
print("Average image height",df_image['height'].mean())
print("Average image width",df_image['width'].mean())
# Out:
# Average image height 386.74721189591077
# Average image width 443.33153981608297

# %%
#Assignment 4
4.	What are Convolutional Neural Networks and how are they better than regular only Fully Connected Neural Networks? 

Convolutional neural networks works in the concept of image size reduction focussing on the are of interest.
It is better than FCNN because of feature extraction and also reducting the image size and thereby causing the less weights and biases and less neurons at the input layer after flattening
It reduces the input parameters to some extent.

FCNN has only static parameters based o the image size and there is no way to reduce it.

# %%
#Assignment 5
5.	The major components of a CNN topology are Filter/ Kernel, Strides, etc. Explain mathematically the output of a single CNN layer and how it is impacted by strides? 

Filter - IT is  a square matrix of numbers that is random at the beginning and then is updated by the SGD depending on the loss function calculation
Usually 3* 3 filter size is widely used.

STrides - They are movement or steps of filters to be taken to stride through right and down of the filters against the original image  thereby reducing the image size by element wise multiplication

Mathematical formula = ((I - F +[P] ) / S ) + 1

I - input image
F - filter image
P - Padding - can be present  introduced basis the need
S - Stride size

Strides determine the reduction of the image size and also overlaps.

It is in the denominator of the mathematical formula and will contribute the size of the outptut image significantly

S= F , image pixel will be touched once

S> F - potential loss of pixel capture

S < F- Overlap occurs

# %%
#assignment 6
6.	For a single channel image, size (9x9) and a filter of size (2x2) and stride (2x2), calculate the output. Is padding required ? What is the output size of this convoluted feature? 

Output = ((I - F +[P] ) / S ) + 1
 
      = ((9-2 + 1) / 2 ) + 1

      =5 * 5

# %%
#assignemnt 7
7.	For a particular problem if the error is not dipping below a standard point, what are the techniques used to reduce error ? Explain the methodology in depth and with examples. 

Simplifying The Model
The first step when dealing with overfitting is to decrease the complexity of the model. To decrease the complexity, 
we can simply remove layers or reduce the number of neurons to make the network smaller. While doing this, it is important to calculate the
 input and output dimensions of the various layers involved in the neural network. There is no general rule on how much to remove or how large your network should be.
  But, if your neural network is overfitting, try making it smaller.

Early Stopping
Early stopping is a form of regularization while training a model with an iterative method, such as gradient descent. 
Since all the neural networks learn exclusively by using gradient descent, early stopping is a technique applicable to all the problems. 
This method update the model so as to make it better fit the training data with each iteration. Up to a point, this improves the model’s performance on data on the test set.
 Past that point however, improving the model’s fit to the training data leads to increased generalization error. Early stopping rules provide guidance as to how many iterations
  can be run before the model begins to overfit.

  Use Data Augmentation
In the case of neural networks, data augmentation simply means increasing size of the data that is increasing the number of images 
present in the dataset. Some of the popular image augmentation techniques are flipping, translation, rotation, scaling, changing brightness, adding noise etcetera.

Use Regularization
Regularization is a technique to reduce the complexity of the model. It does so by adding a penalty term to the loss function. 
The most common techniques are known as L1 and L2 regularization

Use Dropouts
Dropout is a regularization technique that prevents neural networks from overfitting. 
Regularization methods like L1 and L2 reduce overfitting by modifying the cost function. Dropout on
 the other hand, modify the network itself. It randomly drops neurons from the neural network during 
 training in each iteration. When we drop different sets of neurons, it’s equivalent to training different
  neural networks. The different networks will overfit in different ways, so the net effect of dropout will be
   to reduce overfitting.
